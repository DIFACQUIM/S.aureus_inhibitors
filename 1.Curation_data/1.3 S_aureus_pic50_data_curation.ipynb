# %% [markdown]
# ## **Data curation**

# %% [markdown]
# This section was adapted by Alberto Marban from https://difacquim.gitbook.io/quimioinformatica
#
# Manual review of the original references was conducted to resolve discrepancies in the pIC<sub>50</sub> values of duplicate *S. aureus* compounds recorded in ChEMBL from df_fabi_s_aureus_IC50_for_manual_revision.xlsx. The selected entries were written to a new file named df_fabi_s_aureus_IC50_removal_same_smiles_assays_manual_selection.xlsx.

# %%
# !pip install -q rdkit 
# !pip install -q molvs

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import PandasTools
from rdkit.Chem import rdMolDescriptors
from molvs.standardize import Standardizer
from molvs.charge import Uncharger, Reionizer
from molvs.fragment import LargestFragmentChooser
from molvs.tautomer import TautomerCanonicalizer
from rdkit.Chem.rdmolops import GetFormalCharge, RemoveStereochemistry

# %%
# Load excel file
data = pd.read_excel('df_fabi_s_aureus_IC50_removal_samesmailes_assays_munualselection.xlsx')

# %%
#########################################Funciones MolVS######################################################################
#Definir funciones
STD = Standardizer() # Get the standardized version of a given SMILES string (canonical SMILES).
LFC = LargestFragmentChooser() # Select the largest fragment from a salt (ionic compound).
UC = Uncharger() # Charge corrections are applied to ensure, for example, that free metals are correctly ionized.
RI = Reionizer() # Neutralize molecule by adding/removing hydrogens.
TC = TautomerCanonicalizer()  # Return a tautormer “reasonable” from a chemist’s point, but isn’t guarante

# %%
data.columns
# Out:
# Index(['action_type', 'assay_chembl_id', 'assay_description',
#        'canonical_smiles', 'ligand_efficiency', 'molecule_chembl_id',
#        'molecule_pref_name', 'standard_type', 'standard_units',
#        'standard_value', 'target_chembl_id', 'target_organism', 'type',
#        'units', 'value'],
#       dtype='object')

# %%
len(data)
# Out:
# 248

# %%
#Función para curado
def pretreatment(smi):
    try:
        mol = Chem.MolFromSmiles(smi)
        if mol == None:
            #If rdkit could not parse the smiles, returns Error 1
            return "Error 1"
        else:
            mol = STD(mol)
            mol = LFC(mol)

            allowed_elements = {"H","B","C","N","O","F","Si","P","S","Cl","Se","Br","I"}
            actual_elements = set([atom.GetSymbol() for atom in mol.GetAtoms()])
            if len(actual_elements-allowed_elements) == 0:
                mol = UC(mol)
                mol = RI(mol)
                #RemoveStereochemistry(mol)
                mol = TC(mol)
                return Chem.MolToSmiles(mol)
            else:
                # If molecule contains other than the allowed elements, return "Error 2"
                return "Error 2"
    except:
        return "Something else was found"

# %%
#Nueva columna de SMILES
data["NEW_SMILES"] = [pretreatment(x) for x in data["canonical_smiles"]]
data.head()
# Out:
#   action_type assay_chembl_id  \
# 0         NaN    CHEMBL819485
# 1         NaN    CHEMBL819485
# 2         NaN    CHEMBL819485
# 3         NaN    CHEMBL819485
# 4         NaN    CHEMBL819485
#
#                                    assay_description  \
# 0  Concentration required for the 50% inhibition ...
# 1  Concentration required for the 50% inhibition ...
# 2  Concentration required for the 50% inhibition ...
# 3  Concentration required for the 50% inhibition ...
# 4  Concentration required for the 50% inhibition ...
#
#                                     canonical_smiles  \
# 0     CC(=O)N(C)Cc1cc(C(=O)N(C)Cc2cc3ccccc3n2C)ccc1N
# 1              CN(Cc1cc2ccccc2n1C)C(=O)CCc1ccc(N)nc1
# 2       CN1Cc2cc(C(=O)N(C)Cc3cc4ccccc4n3C)ccc2NCC1=O
# 3                   CN(Cc1cc2ccccc2n1C)C(=O)c1ccccc1
# 4  COC(=O)CC1Nc2ccc(C(=O)N(C)Cc3cc4ccccc4n3C)cc2C...
#
#                                    ligand_efficiency molecule_chembl_id  \
# 0  {'bei': '13.67', 'le': '0.25', 'lle': '2.16', ...       CHEMBL109420
# 1  {'bei': '12.49', 'le': '0.23', 'lle': '1.28', ...       CHEMBL109484
# 2  {'bei': '12.41', 'le': '0.23', 'lle': '1.84', ...       CHEMBL109511
# 3                                                NaN       CHEMBL109805
# 4  {'bei': '10.66', 'le': '0.20', 'lle': '2.01', ...       CHEMBL110480
#
#   molecule_pref_name standard_type standard_units  standard_value  \
# 0                NaN          IC50             nM          6700.0
# 1                NaN          IC50             nM         93700.0
# 2                NaN          IC50             nM         21200.0
# 3                NaN          IC50             nM        100000.0
# 4                NaN          IC50             nM         16500.0
#
#   target_chembl_id        target_organism  type units  value  \
# 0       CHEMBL3994  Staphylococcus aureus  IC50    uM    6.7
# 1       CHEMBL3994  Staphylococcus aureus  IC50    uM   93.7
# 2       CHEMBL3994  Staphylococcus aureus  IC50    uM   21.2
# 3       CHEMBL3994  Staphylococcus aureus  IC50    uM  100.0
# 4       CHEMBL3994  Staphylococcus aureus  IC50    uM   16.5
#
#                                           NEW_SMILES
# 0     CC(=O)N(C)Cc1cc(C(=O)N(C)Cc2cc3ccccc3n2C)ccc1N
# 1          CN(Cc1cc2ccccc2n1C)C(=O)CCc1ccc(=N)[nH]c1
# 2       CN1Cc2cc(C(=O)N(C)Cc3cc4ccccc4n3C)ccc2NCC1=O
# 3                   CN(Cc1cc2ccccc2n1C)C(=O)c1ccccc1
# 4  COC(=O)CC1Nc2ccc(C(=O)N(C)Cc3cc4ccccc4n3C)cc2C...

# %%
# Eliminar smiles no leído por RDKit
data = data[data["NEW_SMILES"] != "Error 1"]
# Eliminar smiles que contiene átomos no permitidos
data = data[data["NEW_SMILES"] != "Error 2"]
# Eliminar otros errores
data = data[data["NEW_SMILES"] != "Something else was found"].reset_index(drop=True)

# %%
# Eliminar duplicados
data = data.drop_duplicates(subset=["NEW_SMILES"], keep="first").reset_index(drop=True)
print(data.shape)
data
# Out:
# (246, 16)
#     action_type assay_chembl_id  \
# 0           NaN    CHEMBL819485
# 1           NaN    CHEMBL819485
# 2           NaN    CHEMBL819485
# 3           NaN    CHEMBL819485
# 4           NaN    CHEMBL819485
# ..          ...             ...
# 241         NaN    CHEMBL677574
# 242         NaN    CHEMBL677574
# 243         NaN    CHEMBL677574
# 244         NaN    CHEMBL677574
# 245         NaN   CHEMBL3625533
#
#                                      assay_description  \
# 0    Concentration required for the 50% inhibition ...
# 1    Concentration required for the 50% inhibition ...
# 2    Concentration required for the 50% inhibition ...
# 3    Concentration required for the 50% inhibition ...
# 4    Concentration required for the 50% inhibition ...
# ..                                                 ...
# 241  Antibacterial activity against Staphylococcus ...
# 242  Antibacterial activity against Staphylococcus ...
# 243  Antibacterial activity against Staphylococcus ...
# 244  Antibacterial activity against Staphylococcus ...
# 245  Inhibitory activity against Enoyl-ACP reductas...
#
#                                       canonical_smiles  \
# 0       CC(=O)N(C)Cc1cc(C(=O)N(C)Cc2cc3ccccc3n2C)ccc1N
# 1                CN(Cc1cc2ccccc2n1C)C(=O)CCc1ccc(N)nc1
# 2         CN1Cc2cc(C(=O)N(C)Cc3cc4ccccc4n3C)ccc2NCC1=O
# 3                     CN(Cc1cc2ccccc2n1C)C(=O)c1ccccc1
# 4    COC(=O)CC1Nc2ccc(C(=O)N(C)Cc3cc4ccccc4n3C)cc2C...
# ..                                                 ...
# 241  Cc1cc(C(=O)N2CCc3c(n(Cc4ccc(O)cc4)c4ccccc34)C2...
# 242  O=C(c1ccc(O)c(Cl)c1)N1CCc2c(n(Cc3ccc(O)cc3)c3c...
# 243  Cc1cc(C(=O)N2CCc3c(n(Cc4ccc(O)cc4)c4ccccc34)C2...
# 244  O=C(c1ccc(O)cc1)N1CCc2c([nH]c3ccccc23)C1c1ccc(...
# 245                       Oc1cc(Cl)ccc1Oc1ccc(Cl)cc1Cl
#
#                                      ligand_efficiency molecule_chembl_id  \
# 0    {'bei': '13.67', 'le': '0.25', 'lle': '2.16', ...       CHEMBL109420
# 1    {'bei': '12.49', 'le': '0.23', 'lle': '1.28', ...       CHEMBL109484
# 2    {'bei': '12.41', 'le': '0.23', 'lle': '1.84', ...       CHEMBL109511
# 3                                                  NaN       CHEMBL109805
# 4    {'bei': '10.66', 'le': '0.20', 'lle': '2.01', ...       CHEMBL110480
# ..                                                 ...                ...
# 241  {'bei': '12.98', 'le': '0.24', 'lle': '0.62', ...        CHEMBL73455
# 242  {'bei': '15.70', 'le': '0.30', 'lle': '1.85', ...        CHEMBL73580
# 243  {'bei': '16.35', 'le': '0.30', 'lle': '2.13', ...        CHEMBL73953
# 244  {'bei': '11.84', 'le': '0.21', 'lle': '0.18', ...        CHEMBL74072
# 245  {'bei': '24.71', 'le': '0.57', 'lle': '2.01', ...          CHEMBL849
#
#     molecule_pref_name standard_type standard_units  standard_value  \
# 0                  NaN          IC50             nM          6700.0
# 1                  NaN          IC50             nM         93700.0
# 2                  NaN          IC50             nM         21200.0
# 3                  NaN          IC50             nM        100000.0
# 4                  NaN          IC50             nM         16500.0
# ..                 ...           ...            ...             ...
# 241                NaN          IC50             nM          2900.0
# 242                NaN          IC50             nM           160.0
# 243                NaN          IC50             nM           180.0
# 244                NaN          IC50             nM         28100.0
# 245          TRICLOSAN          IC50             nM           440.0
#
#     target_chembl_id        target_organism  type units   value  \
# 0         CHEMBL3994  Staphylococcus aureus  IC50    uM    6.70
# 1         CHEMBL3994  Staphylococcus aureus  IC50    uM   93.70
# 2         CHEMBL3994  Staphylococcus aureus  IC50    uM   21.20
# 3         CHEMBL3994  Staphylococcus aureus  IC50    uM  100.00
# 4         CHEMBL3994  Staphylococcus aureus  IC50    uM   16.50
# ..               ...                    ...   ...   ...     ...
# 241       CHEMBL3994  Staphylococcus aureus  IC50    uM    2.90
# 242       CHEMBL3994  Staphylococcus aureus  IC50    uM    0.16
# 243       CHEMBL3994  Staphylococcus aureus  IC50    uM    0.18
# 244       CHEMBL3994  Staphylococcus aureus  IC50    uM   28.10
# 245       CHEMBL3994  Staphylococcus aureus  IC50    uM    0.44
#
#                                             NEW_SMILES
# 0       CC(=O)N(C)Cc1cc(C(=O)N(C)Cc2cc3ccccc3n2C)ccc1N
# 1            CN(Cc1cc2ccccc2n1C)C(=O)CCc1ccc(=N)[nH]c1
# 2         CN1Cc2cc(C(=O)N(C)Cc3cc4ccccc4n3C)ccc2NCC1=O
# 3                     CN(Cc1cc2ccccc2n1C)C(=O)c1ccccc1
# 4    COC(=O)CC1Nc2ccc(C(=O)N(C)Cc3cc4ccccc4n3C)cc2C...
# ..                                                 ...
# 241  Cc1cc(C(=O)N2CCc3c(n(Cc4ccc(O)cc4)c4ccccc34)C2...
# 242  O=C(c1ccc(O)c(Cl)c1)N1CCc2c(n(Cc3ccc(O)cc3)c3c...
# 243  Cc1cc(C(=O)N2CCc3c(n(Cc4ccc(O)cc4)c4ccccc34)C2...
# 244  O=C(c1ccc(O)cc1)N1CCc2c([nH]c3ccccc23)C1c1ccc(...
# 245                       Oc1cc(Cl)ccc1Oc1ccc(Cl)cc1Cl
#
# [246 rows x 16 columns]

# %%
len(data)
# Out:
# 246

# %%
# Guardar dataframe como archivo csv
data.to_excel("s_aureus_fabI_curated_data.xlsx", index=False)
